# %%
import numpy as np
import sys
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
import joblib
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
import datetime
from sklearn.svm import SVR
import sklearn.svm as svm
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from datetime import timedelta

# %%
#pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\administrator\anaconda3\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
column_names = [
    'Fran Datum Tid (UTC)', 'till', 'day', 'temperature', 'Kvalitet', 'Tidsutsnitt:', 'Unnamed: 5']
column_names_used = [
    'Fran Datum Tid (UTC)', 'till', 'day']

data1 = pd.read_csv('C:/Users/Administrator/Desktop/Phani-UNH/intro- AI/Weather_Prediction/Archive_data.csv', sep=';', skiprows=3607, names=column_names)
data2 = pd.read_csv('C:/Users/Administrator/Desktop/Phani-UNH/intro- AI/Weather_Prediction/Latest_data.csv', sep=';', skiprows=15, names=column_names)


def make_numeric_values(arr, title):
    new_arr = []
    for date in arr[title]:
        new_date = make_date(date)
        new_arr.append(new_date)
    arr[title] = new_arr

def fix_array(arr):
    for name in column_names_used:
        make_numeric_values(arr, name)

def make_date(date):
    new_date = date.split(' ')
    new_date = new_date[0]
    new_date = new_date.split('-')
    new_number = ''
    first = True
    for number in new_date:
        if first:
            first = False
        else:
            new_number = new_number + number
    return new_number

def convert_date_to_string(plus_days):
    date = datetime.datetime.today() + timedelta(days=plus_days)
    date = date.strftime("%Y-%m-%d %H:%M:%S") 
    date = date.split(' ')
    date = date[0]
    date = date.split('-')
    date = date[1]+date[2]
    return date

# THIS IS WHERE THE MODEL GETS TRAINED
# if you want to use this in your own project this is the method you want to study

def get_the_weather(date):
    weather = data1.day
    print(weather)
    temp = data1.temperature
    print(temp)
    #for i in range(0, len(weather)):
    #    day = datetime.datetime.strptime(weather[i], "%Y-%m-%d")
    #    if (day == date):
    #        return temp[i]


def train():
    
    data1 = pd.read_csv('C:/Users/Administrator/Desktop/Phani-UNH/intro- AI/Weather_Prediction/Archive_data.csv', sep=';', skiprows=3607, names=column_names)
    #print data1
    #sys.exit()
    data2 = pd.read_csv('C:/Users/Administrator/Desktop/Phani-UNH/intro- AI/Weather_Prediction/Latest_data.csv', sep=';', skiprows=15, names=column_names)
    data1 = data2.append(data1)
    data1 = data1.drop('Tidsutsnitt:', axis=1)
    X = data1.drop(["temperature"], axis=1)
    X = X.drop(['Kvalitet'], axis = 1)
    X = X.drop(['Unnamed: 5'], axis = 1)
    fix_array(X)

    y = data1['temperature']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=123)

    tree_model = DecisionTreeRegressor()

    tree_model.fit(X_train, y_train)
    joblib.dump(tree_model, 'weather_predictor.pkl')
    print("-" * 48)
    print("\nDone training\n")
    print("-" * 48)

def predict_weather():
    tree_model = joblib.load('weather_predictor.pkl')

    print("-" * 48)
    print("Enter the details of the date you would like to predict")
    print("\n")
    option = input("Year: ")
    year = option
    option = input("Month number (00): ")
    month = option
    option = input("Day number (00): ")
    theday = option

    day = str(month) + str(theday)
    
    date = [
        [day, 
        (str(int(day) + 1)), 
        (day)]
    ]
    temp = tree_model.predict(date)[0]
    print("-" * 48)
    print("\nThe temperature is estimated to be: " + str(temp) + "\n")
    print("-" * 48)

def run_program(option):
    if option == 1:
        #print("1")
        print("-" * 48)
        print("Enter the details of the date you would like to look up weather")
        print("\n")
        option = input("Year: ")
        year = option
        option = input("Month number (00): ")
        month = option
        option = input("Day number (00): ")
        theday = option
        day = str(month) + str(theday)
        date = [
            [day, 
            (str(int(day) + 1)), 
            (day)]
            ]
        get_the_weather(date)
    elif option == 2:
        predict_weather()

def run_menu():
    print("*" *48)
    print("-" *10 + " What would you like to do? " + "-" * 10)
    print("\n")
    print("1. Look up the weather on a specific day")
    print("2. Predict the weather on a specific day")
    print("3. Train ")
    print("\n")

    option = int( input("Enter option: "))

    while True:
        if option == 2 or option == 1 or option == 9 or option == 3:
            break
        option = input("Enter option: ")
    return option

if __name__== "__main__":
    # X is our input variables that will be used to predict y which is our output so temperature
    # the data in X needs to be converted to numeric values to simplify our process
    while True:
        option = run_menu()
        if option == 9:
            break
        if option == 3:
            train()
        else:
            run_program(option)
# Out:
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 1
# ------------------------------------------------
# Enter the details of the date you would like to look up weather
#
#
# Year: 2020
# Month number (00): 12
# Day number (00): 12
# 0        1971-01-02
# 1        1971-01-03
# 2        1971-01-04
# 3        1971-01-05
# 4        1971-01-06
#             ...
# 14663    2019-01-27
# 14664    2019-01-28
# 14665    2019-01-29
# 14666    2019-01-30
# 14667    2019-01-31
# Name: day, Length: 14668, dtype: object
# 0        -8.1
# 1        -3.3
# 2        -0.8
# 3        -2.8
# 4       -10.1
#          ...
# 14663    -1.5
# 14664     0.1
# 14665    -4.6
# 14666    -2.5
# 14667    -0.1
# Name: temperature, Length: 14668, dtype: float64
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 3
# ------------------------------------------------
#
# Done training
#
# ------------------------------------------------
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 2
# ------------------------------------------------
# Enter the details of the date you would like to predict
#
#
# Year: 2019
# Month number (00): 02
# Day number (00): 02
# ------------------------------------------------
#
# The temperature is estimated to be: 0.6545454545454544
#
# ------------------------------------------------
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 3
# ------------------------------------------------
#
# Done training
#
# ------------------------------------------------
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 2
# ------------------------------------------------
# Enter the details of the date you would like to predict
#
#
# Year: 2019
# Month number (00): 03
# Day number (00): 10
# ------------------------------------------------
#
# The temperature is estimated to be: 1.5681818181818181
#
# ------------------------------------------------
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train
#
#
# Enter option: 3
# ------------------------------------------------
#
# Done training
#
# ------------------------------------------------
# ************************************************
# ---------- What would you like to do? ----------
#
#
# 1. Look up the weather on a specific day
# 2. Predict the weather on a specific day
# 3. Train

# %%
1

# %%
1

# %%
2

# %%
2
